# %% [markdown]
# # MAC için ilk optimizasyon
#
# Dosya ismi MAC2
#
# input: `# opt freq b3lyp/6-31g(d,p)`
#
# Solvation: No
#
# ## Geopt + Freq sonrası
#
# 3D Structure:
#
# <img src="MAC0/MAC_0_structure_2.png" width="320" height="220">
#
# </>
#
# |Overview Tab Data Section:| |
# | --- | --- |
# |MAC_GO| |
# |D:/backups/Depo1/ChemChem/3/MAC_sunum/MAC1/MAC1.chk|
# |File Type|  .chk|
# |Calculation Type|  FREQ|
# |Calculation Method|  RB3LYP|
# |Basis Set|  6-31G(D,P)|
# |Charge|  0|
# |Spin|  Singlet|
# |Solvation|  scrf=check|
# |Electronic Energy|  -912.6865 Hartree|
# |RMS Gradient Norm|  7.0776569e-06 Hartree/Bohr|
# |Imaginary Freq|  |
# |Dipole Moment|  2.3790574 Debye|
# |Polarizability (α)| = 91.86722 a.u.|
# |Point Group|  |

# %% [markdown]
# # MAC 1. Olası Geometri
#
# Dosya İsmi MAC1
#
# Olası bağlanma:
#
# <img src="MAC1/MAC_1_structure_1.png" width="320" height="220">
#
# input: `# opt freq rb3lyp/6-31g(d,p) scrf=check genchk`
#
# Solvation: No
#
# ## Geopt + Freq sonrası
#
# 3D Structure:
#
# <img src="MAC1/MAC_1_structure_2.png" width="320" height="220">
#
# </>
#
# | Overview Tab Data Section: | |
# | --- | --- |
# | MAC_GO | |
# | D:/backups/Depo1/ChemChem/3/MAC_sunum/MAC1/MAC1.chk |
# | File Type | .chk |
# | Calculation Type | FREQ |
# | Calculation Method | RB3LYP |
# | Basis Set | 6-31G(D,P) |
# | Charge | 0 |
# | Spin | Singlet |
# | Solvation | scrf=check |
# | Electronic Energy | -912.6865 Hartree |
# | RMS Gradient Norm | 7.032682e-06 Hartree/Bohr |
# | Imaginary Freq |  |
# | Dipole Moment | 2.379044 Debye |
# | Polarizability (?) | 91.867235 a.u. |
# | Point Group |  |
